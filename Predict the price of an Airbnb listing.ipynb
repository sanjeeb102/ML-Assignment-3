# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\sanje_crlv28m\Downloads\airbnb_listing_train.csv\airbnb_listing_train.csv")
df.head()
# Out:
#          id                                             name    host_id  \
# 0  11602914              Luxury home 100m2+garden in center!    3123809
# 1  13289321                      East is where your home is!   10259430
# 2  40779315  Amsterdam Central - LUXURY house in BUSY STREET  224969266
# 3   7820311                       great appartment down town     693472
# 4  27346603    Private room with canal view in peaceful area   41888346
#
#    host_name  neighbourhood_group            neighbourhood  latitude  \
# 0  Marjolein                  NaN  De Pijp - Rivierenbuurt  52.35368
# 1        Ana                  NaN                 Oud-Oost  52.35728
# 2       Mark                  NaN             Centrum-West  52.37582
# 3      Ayden                  NaN               Westerpark  52.37792
# 4     Alissa                  NaN               Westerpark  52.38051
#
#    longitude        room_type  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Shape
df.shape
# Out:
# (12901, 16)

# %%
# Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365', 'price'],
#       dtype='object')

# %%
df.head(10)
# Out:
#          id                                               name    host_id  \
# 0  11602914                Luxury home 100m2+garden in center!    3123809
# 1  13289321                        East is where your home is!   10259430
# 2  40779315    Amsterdam Central - LUXURY house in BUSY STREET  224969266
# 3   7820311                         great appartment down town     693472
# 4  27346603      Private room with canal view in peaceful area   41888346
# 5   6119654                  Central&Cosy place @ Rijksmuseum!    4056223
# 6   1955400                Gorgeous family home near Museum Sq    1326792
# 7  14667779     Spacious and stylish apartment in buzzing East   30268954
# 8  11204463                  Room in light & stylish apartment    8795077
# 9  13600782  Spacious apartment with garden and awesome kit...   15331870
#
#       host_name  neighbourhood_group            neighbourhood  latitude  \
# 0     Marjolein                  NaN  De Pijp - Rivierenbuurt  52.35368
# ...

# %%
df.tail(10)
# Out:
#              id                                               name    host_id  \
# 12891  19355375                          COZY APARTMENT IN DE PIJP  127305928
# 12892   6356312                  Great spacious house with rooftop   10390341
# 12893  40830384               Stylish city apartment with balcony!  221415522
# 12894  27569750              Cozy and quite room in Amsterdam Zuid   70048505
# 12895   4634719                     Lovely modern & cosy apartment    7830766
# 12896  20757739  Quiet stylish private room 15 mins to city  ce...   63932037
# 12897   1055570  Beautiful, spacious apt. with great views @ IJ...    5813322
# 12898  13178435                Great apartment de Pijp/Albert Cuyp   46370427
# 12899  21963760           Stylish apartment in an amazing location    4895882
# 12900  33726315                   Amsterdam Apartments First Floor  203460948
#
#        host_name  neighbourhood_group             neighbourhood  latitude  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12901 entries, 0 to 12900
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              12901 non-null  int64
#  1   name                            12879 non-null  object
#  2   host_id                         12901 non-null  int64
#  3   host_name                       12893 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   12901 non-null  object
#  6   latitude                        12901 non-null  float64
#  7   longitude                       12901 non-null  float64
#  8   room_type                       12901 non-null  object
#  9   minimum_nights                  12901 non-null  int64
#  10  number_of_reviews               12901 non-null  int64
#  11  last_review                     11305 non-null  object
# ...

# %%
df.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  1.290100e+04  1.290100e+04                  0.0  12901.000000
# mean   1.984923e+07  6.321700e+07                  NaN     52.365313
# std    1.216241e+07  8.010814e+07                  NaN      0.016418
# min    2.016800e+04  3.592000e+03                  NaN     52.289270
# 25%    9.869642e+06  8.948269e+06                  NaN     52.355190
# 50%    1.874939e+07  2.711601e+07                  NaN     52.364570
# 75%    2.914232e+07  8.337686e+07                  NaN     52.375110
# max    4.370900e+07  3.490175e+08                  NaN     52.425090
#
#           longitude  minimum_nights  number_of_reviews  reviews_per_month  \
# count  12901.000000    12901.000000       12901.000000       11305.000000
# mean       4.889744        3.542516          24.803194           0.748501
# std        0.036016       15.154077          53.406134           1.260791
# ...

# %%
o = df.dtypes[df.dtypes == 'object'].index
df[o].describe()
# Out:
#              name host_name           neighbourhood        room_type  \
# count       12879     12893                   12901            12901
# unique      12653      4536                      22                4
# top     Amsterdam   Martijn  De Baarsjes - Oud-West  Entire home/apt
# freq           28        76                    2209            10064
#
#        last_review
# count        11305
# unique        1495
# top     08-03-2020
# freq           269

# %%
df.nunique()
# Out:
# id                                12901
# name                              12653
# host_id                           11601
# host_name                          4536
# neighbourhood_group                   0
# neighbourhood                        22
# latitude                           5227
# longitude                          7887
# room_type                             4
# minimum_nights                       56
# number_of_reviews                   362
# last_review                        1495
# reviews_per_month                   610
# calculated_host_listings_count       26
# availability_365                    366
# price                               400
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 22
# host_id                               0
# host_name                             8
# neighbourhood_group               12901
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        1596
# reviews_per_month                  1596
# calculated_host_listings_count        0
# availability_365                      0
# price                                 0
# dtype: int64

# %%
# Visualizing Missing values in dataset
plt.figure(figsize=(12, 10))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.tight_layout()

# %%
# Treating the missing values
df.drop('neighbourhood_group', axis=1, inplace=True)

# %%
df.head()
# Out:
#          id                                             name    host_id  \
# 0  11602914              Luxury home 100m2+garden in center!    3123809
# 1  13289321                      East is where your home is!   10259430
# 2  40779315  Amsterdam Central - LUXURY house in BUSY STREET  224969266
# 3   7820311                       great appartment down town     693472
# 4  27346603    Private room with canal view in peaceful area   41888346
#
#    host_name            neighbourhood  latitude  longitude        room_type  \
# 0  Marjolein  De Pijp - Rivierenbuurt  52.35368    4.90177  Entire home/apt
# 1        Ana                 Oud-Oost  52.35728    4.92052  Entire home/apt
# 2       Mark             Centrum-West  52.37582    4.89850  Entire home/apt
# 3      Ayden               Westerpark  52.37792    4.87300  Entire home/apt
# 4     Alissa               Westerpark  52.38051    4.87493     Private room
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
df['name'].isnull().sum()
# Out:
# 22

# %%
n = df.loc[pd.isna(df['name']), :].index
df.loc[n]
# Out:
#              id name   host_id host_name            neighbourhood  latitude  \
# 415    12397008  NaN    400638     Misha             Centrum-West  52.37772
# 2021   12839657  NaN  66012359    Emilie   De Baarsjes - Oud-West  52.36954
# 3248   10152802  NaN  24138541     Maran          Watergraafsmeer  52.35727
# 4660    9074767  NaN  47328696     Rowan               Noord-West  52.40172
# 5620   10331856  NaN  12657324    Denise               Westerpark  52.38327
# 6021    7171007  NaN  12493511   Pauline             Centrum-West  52.37365
# 6291    8037965  NaN  17097221     Mario            Bos en Lommer  52.37697
# 6300   12130212  NaN  65095912    Martin             Centrum-West  52.37278
# 7072   12643722  NaN  68671201    Thomas             Centrum-Oost  52.37016
# 7826    9383811  NaN  26073108   Maurane             Centrum-West  52.36978
# 7983    4683947  NaN  24220387     Tessa                     Zuid  52.34729
# ...

# %%
df['name'].value_counts()
# Out:
# Amsterdam                                                  28
# Spacious apartment near Vondelpark                          6
# Spacious apartment in Amsterdam                             5
# Lovely apartment in Amsterdam                               5
# Cosy apartment near Vondelpark                              4
#                                                            ..
# Easy room in Oud West                                       1
# Quiet, Cosy & private studio near Leidseplein & museums     1
# cozy apartment                                              1
# Luxurious & modern 3 room apartment                         1
# Amsterdam Apartments First Floor                            1
# Name: name, Length: 12653, dtype: int64

# %%
# EDA
plt.figure(figsize=(12, 10))
sns.distplot(df['price'])
plt.tight_layout()
# Out:
# C:\Users\sanje_crlv28m\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12, 10))
sns.boxplot(df['price'])
plt.tight_layout()
# Out:
# C:\Users\sanje_crlv28m\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['price'].describe()
# Out:
# count    12901.000000
# mean       166.959538
# std        234.794630
# min          6.000000
# 25%         99.000000
# 50%        135.000000
# 75%        190.000000
# max       9000.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df.corr(), annot = True)
plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x= 'room_type', order= df['room_type'].value_counts().index,data= df,palette='Accent')
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='count'>

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# price                               int64
# dtype: object

# %%
df.nunique()
# Out:
# id                                12901
# name                              12653
# host_id                           11601
# host_name                          4536
# neighbourhood                        22
# latitude                           5227
# longitude                          7887
# room_type                             4
# minimum_nights                       56
# number_of_reviews                   362
# last_review                        1495
# reviews_per_month                   610
# calculated_host_listings_count       26
# availability_365                    366
# price                               400
# dtype: int64

# %%
df.head(10)
# Out:
#          id                                               name    host_id  \
# 0  11602914                Luxury home 100m2+garden in center!    3123809
# 1  13289321                        East is where your home is!   10259430
# 2  40779315    Amsterdam Central - LUXURY house in BUSY STREET  224969266
# 3   7820311                         great appartment down town     693472
# 4  27346603      Private room with canal view in peaceful area   41888346
# 5   6119654                  Central&Cosy place @ Rijksmuseum!    4056223
# 6   1955400                Gorgeous family home near Museum Sq    1326792
# 7  14667779     Spacious and stylish apartment in buzzing East   30268954
# 8  11204463                  Room in light & stylish apartment    8795077
# 9  13600782  Spacious apartment with garden and awesome kit...   15331870
#
#       host_name            neighbourhood  latitude  longitude  \
# 0     Marjolein  De Pijp - Rivierenbuurt  52.35368    4.90177
# ...

# %%
df.drop(['id','name', 'host_name', 'last_review'],axis=1, inplace=True)

# %%
df = pd.concat([df, pd.get_dummies(df['room_type'], prefix='d')],axis=1)

# %%
df.head()
# Out:
#      host_id            neighbourhood  latitude  longitude        room_type  \
# 0    3123809  De Pijp - Rivierenbuurt  52.35368    4.90177  Entire home/apt
# 1   10259430                 Oud-Oost  52.35728    4.92052  Entire home/apt
# 2  224969266             Centrum-West  52.37582    4.89850  Entire home/apt
# 3     693472               Westerpark  52.37792    4.87300  Entire home/apt
# 4   41888346               Westerpark  52.38051    4.87493     Private room
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               3                 13               0.27
# 1               4                 14               0.29
# 2               2                  9               1.65
# 3               3                 42               0.72
# 4               2                 89               4.02
#
#    calculated_host_listings_count  availability_365  price  d_Entire home/apt  \
# 0                               1                 0    220                  1
# ...

# %%
df['neighbourhood'] = df['neighbourhood'].astype('category')

# %%
df.dtypes
# Out:
# id                                   int64
# name                                object
# host_id                              int64
# host_name                           object
# neighbourhood                     category
# latitude                           float64
# longitude                          float64
# room_type                           object
# minimum_nights                       int64
# number_of_reviews                    int64
# last_review                         object
# reviews_per_month                  float64
# calculated_host_listings_count       int64
# availability_365                     int64
# price                                int64
# dtype: object

# %%
X = df.drop(['price'],axis=1)

y = df['price']

# %%
X.head()
# Out:
#          id                                             name    host_id  \
# 0  11602914              Luxury home 100m2+garden in center!    3123809
# 1  13289321                      East is where your home is!   10259430
# 2  40779315  Amsterdam Central - LUXURY house in BUSY STREET  224969266
# 3   7820311                       great appartment down town     693472
# 4  27346603    Private room with canal view in peaceful area   41888346
#
#    host_name            neighbourhood  latitude  longitude        room_type  \
# 0  Marjolein  De Pijp - Rivierenbuurt  52.35368    4.90177  Entire home/apt
# 1        Ana                 Oud-Oost  52.35728    4.92052  Entire home/apt
# 2       Mark             Centrum-West  52.37582    4.89850  Entire home/apt
# 3      Ayden               Westerpark  52.37792    4.87300  Entire home/apt
# 4     Alissa               Westerpark  52.38051    4.87493     Private room
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
y.head()
# Out:
# 0    220
# 1    110
# 2    100
# 3    130
# 4     90
# Name: price, dtype: int64
